# %%
from lp_random_gen import random_lp_int
from docplex.mp.advmodel import AdvModel
from docplex.mp.model_reader import ModelReader
from helpers import *
from qiskit.optimization.algorithms.optimization_algorithm import OptimizationResultStatus
DIR = 'SYNTH_DATA/BINARY/'
getPath = lambda fn : DIR+fn+".lp"

# %% [markdown]
# # Create Test Data

# %%
NUM_TESTS = 30
for i in range(1,NUM_TESTS +1):
    lp_bin = random_lp_int(i*2, i, 0, 1)
    model = lp_bin.createLP("test_bin_"+str(i))
    with open(getPath(lp_bin.name), 'w+') as file:
        file.write(model.export_as_lp_string())

# %% [markdown]
# # Solve with DWave Systems

# %%
from dwave.system import DWaveCliqueSampler, LeapHybridSampler

# %%
num_reads = 2000
solvers = [createSolver(LeapHybridSampler()), createSolver(DWaveCliqueSampler(),num_reads), createSolver(num_reads = num_reads)]
solver_names = ["Leap Hybrid", "DWaveClique", "DWaveSampler"]
qps = createModelsFromDir(DIR)

# %%
with open(getPath("results"), 'w+') as file:
    file.write("Start Tests \n \n")

# %%
for qp_name in sorted(qps.keys(), key = lambda name : int(name[name.rfind('_')+1:])) :
    results = [optimizer.solve(qps[qp_name]) for optimizer in solvers]
    if any(res.status == OptimizationResultStatus.SUCCESS for res in results):
        with open(getPath("results"), 'a+') as file:
            file.write("\n ------------------------------------- \n"+qp_name)
            for i in range(len(solvers)):
                res = results[i]
                sname = solver_names[i]
                file.write("\n"+sname)
                if res.status == OptimizationResultStatus.SUCCESS:
                    cres  = qps[qp_name].model.solve()
                    if res.fval != cres.get_objective_value():
                        file.write("\n optimal value DWave   "+str(res.fval) + "  ,  cplex:"+ str(cres.get_objective_value()))
                        file.write("\n"+str(res.x)+"   cplex:"+str(cres.get_all_values()))
                    else:
                        file.write("\n found solution!")
                else:
                    file.write("\n"+str(res.status))   
    else:
        print(qp_name)
        break
# Out:
# * No objective to optimize - searching for a feasible solution
# * No objective to optimize - searching for a feasible solution
# * No objective to optimize - searching for a feasible solution
# constraint A2leb2 is infeasible due to substitution
# constraint A1leb1 is infeasible due to substitution
# constraint A5leb5 is infeasible due to substitution
# constraint A1leb1 is infeasible due to substitution
# constraint A2leb2 is infeasible due to substitution
# constraint A3leb3 is infeasible due to substitution
# constraint A5leb5 is infeasible due to substitution
# constraint A6leb6 is infeasible due to substitution
# constraint A7leb7 is infeasible due to substitution
# constraint A1leb1 is infeasible due to substitution
# constraint A2leb2 is infeasible due to substitution
# constraint A5leb5 is infeasible due to substitution
# constraint A6leb6 is infeasible due to substitution
# constraint A7leb7 is infeasible due to substitution
# constraint A0leb0 is infeasible due to substitution
# constraint A1leb1 is infeasible due to substitution
# constraint A2leb2 is infeasible due to substitution
# constraint A3leb3 is infeasible due to substitution
# constraint A4leb4 is infeasible due to substitution
# constraint A5leb5 is infeasible due to substitution
# constraint A6leb6 is infeasible due to substitution
# constraint A9leb9 is infeasible due to substitution
# constraint A0leb0 is infeasible due to substitution
# constraint A1leb1 is infeasible due to substitution
# constraint A2leb2 is infeasible due to substitution
# constraint A3leb3 is infeasible due to substitution
# constraint A6leb6 is infeasible due to substitution
# constraint A8leb8 is infeasible due to substitution
# constraint A9leb9 is infeasible due to substitution
# constraint A1leb1 is infeasible due to substitution
# constraint A2leb2 is infeasible due to substitution
# constraint A4leb4 is infeasible due to substitution
# constraint A5leb5 is infeasible due to substitution
# constraint A9leb9 is infeasible due to substitution
# constraint A10leb10 is infeasible due to substitution
# constraint A11leb11 is infeasible due to substitution
# constraint A0leb0 is infeasible due to substitution
# constraint A4leb4 is infeasible due to substitution
# constraint A6leb6 is infeasible due to substitution
# constraint A7leb7 is infeasible due to substitution
# constraint A8leb8 is infeasible due to substitution
# constraint A11leb11 is infeasible due to substitution
# constraint A0leb0 is infeasible due to substitution
# constraint A1leb1 is infeasible due to substitution
# constraint A2leb2 is infeasible due to substitution
# constraint A4leb4 is infeasible due to substitution
# constraint A5leb5 is infeasible due to substitution
# constraint A7leb7 is infeasible due to substitution
# constraint A8leb8 is infeasible due to substitution
# constraint A9leb9 is infeasible due to substitution
# constraint A10leb10 is infeasible due to substitution
# constraint A11leb11 is infeasible due to substitution
# constraint A12leb12 is infeasible due to substitution
# constraint A1leb1 is infeasible due to substitution
# constraint A3leb3 is infeasible due to substitution
# constraint A5leb5 is infeasible due to substitution
# constraint A6leb6 is infeasible due to substitution
# constraint A7leb7 is infeasible due to substitution
# constraint A8leb8 is infeasible due to substitution
# constraint A9leb9 is infeasible due to substitution
# constraint A11leb11 is infeasible due to substitution
# constraint A12leb12 is infeasible due to substitution
# constraint A13leb13 is infeasible due to substitution
# constraint A0leb0 is infeasible due to substitution
# constraint A1leb1 is infeasible due to substitution
# constraint A2leb2 is infeasible due to substitution
# constraint A3leb3 is infeasible due to substitution
# constraint A4leb4 is infeasible due to substitution
# constraint A5leb5 is infeasible due to substitution
# constraint A6leb6 is infeasible due to substitution
# constraint A7leb7 is infeasible due to substitution
# constraint A8leb8 is infeasible due to substitution
# constraint A9leb9 is infeasible due to substitution
# constraint A10leb10 is infeasible due to substitution
# constraint A11leb11 is infeasible due to substitution
# constraint A12leb12 is infeasible due to substitution
# constraint A13leb13 is infeasible due to substitution
# constraint A14leb14 is infeasible due to substitution
# constraint A15leb15 is infeasible due to substitution
# constraint A0leb0 is infeasible due to substitution
# constraint A1leb1 is infeasible due to substitution
# constraint A2leb2 is infeasible due to substitution
# constraint A3leb3 is infeasible due to substitution
# constraint A4leb4 is infeasible due to substitution
# constraint A5leb5 is infeasible due to substitution
# constraint A6leb6 is infeasible due to substitution
# constraint A7leb7 is infeasible due to substitution
# constraint A9leb9 is infeasible due to substitution
# constraint A10leb10 is infeasible due to substitution
# constraint A11leb11 is infeasible due to substitution
# constraint A12leb12 is infeasible due to substitution
# constraint A14leb14 is infeasible due to substitution
# constraint A15leb15 is infeasible due to substitution
# constraint A0leb0 is infeasible due to substitution
# constraint A1leb1 is infeasible due to substitution
# constraint A2leb2 is infeasible due to substitution
# constraint A3leb3 is infeasible due to substitution
# constraint A4leb4 is infeasible due to substitution
# constraint A5leb5 is infeasible due to substitution
# constraint A6leb6 is infeasible due to substitution
# constraint A7leb7 is infeasible due to substitution
# constraint A8leb8 is infeasible due to substitution
# constraint A9leb9 is infeasible due to substitution
# constraint A10leb10 is infeasible due to substitution
# constraint A12leb12 is infeasible due to substitution
# constraint A13leb13 is infeasible due to substitution
# constraint A14leb14 is infeasible due to substitution
# constraint A15leb15 is infeasible due to substitution
# constraint A16leb16 is infeasible due to substitution
# constraint A17leb17 is infeasible due to substitution
# constraint A0leb0 is infeasible due to substitution
# constraint A1leb1 is infeasible due to substitution
# constraint A2leb2 is infeasible due to substitution
# constraint A3leb3 is infeasible due to substitution
# constraint A4leb4 is infeasible due to substitution
# constraint A5leb5 is infeasible due to substitution
# constraint A6leb6 is infeasible due to substitution
# constraint A7leb7 is infeasible due to substitution
# constraint A8leb8 is infeasible due to substitution
# constraint A10leb10 is infeasible due to substitution
# constraint A11leb11 is infeasible due to substitution
# constraint A12leb12 is infeasible due to substitution
# constraint A14leb14 is infeasible due to substitution
# constraint A16leb16 is infeasible due to substitution
# constraint A17leb17 is infeasible due to substitution
# constraint A0leb0 is infeasible due to substitution
# constraint A1leb1 is infeasible due to substitution
# constraint A2leb2 is infeasible due to substitution
# constraint A3leb3 is infeasible due to substitution
# constraint A4leb4 is infeasible due to substitution
# constraint A5leb5 is infeasible due to substitution
# constraint A6leb6 is infeasible due to substitution
# constraint A7leb7 is infeasible due to substitution
# constraint A8leb8 is infeasible due to substitution
# constraint A9leb9 is infeasible due to substitution
# constraint A10leb10 is infeasible due to substitution
# constraint A11leb11 is infeasible due to substitution
# constraint A12leb12 is infeasible due to substitution
# constraint A13leb13 is infeasible due to substitution
# constraint A14leb14 is infeasible due to substitution
# constraint A15leb15 is infeasible due to substitution
# constraint A16leb16 is infeasible due to substitution
# constraint A17leb17 is infeasible due to substitution
# constraint A18leb18 is infeasible due to substitution
# constraint A0leb0 is infeasible due to substitution
# constraint A2leb2 is infeasible due to substitution
# constraint A4leb4 is infeasible due to substitution
# constraint A5leb5 is infeasible due to substitution
# constraint A6leb6 is infeasible due to substitution
# constraint A7leb7 is infeasible due to substitution
# constraint A8leb8 is infeasible due to substitution
# constraint A9leb9 is infeasible due to substitution
# constraint A10leb10 is infeasible due to substitution
# constraint A12leb12 is infeasible due to substitution
# constraint A13leb13 is infeasible due to substitution
# constraint A14leb14 is infeasible due to substitution
# constraint A15leb15 is infeasible due to substitution
# constraint A16leb16 is infeasible due to substitution
# constraint A17leb17 is infeasible due to substitution
# constraint A18leb18 is infeasible due to substitution
# constraint A19leb19 is infeasible due to substitution
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-9fbbaf8159e3> in <module>
#       1 for qp_name in sorted(qps.keys(), key = lambda name : int(name[name.rfind('_')+1:])) :
# ----> 2     results = [optimizer.solve(qps[qp_name]) for optimizer in solvers]
#       3     if any(res.status == OptimizationResultStatus.SUCCESS for res in results):
#       4         with open(getPath("results"), 'a+') as file:
#       5             file.write("\n ------------------------------------- \n"+qp_name)
#
# <ipython-input-6-9fbbaf8159e3> in <listcomp>(.0)
#       1 for qp_name in sorted(qps.keys(), key = lambda name : int(name[name.rfind('_')+1:])) :
# ----> 2     results = [optimizer.solve(qps[qp_name]) for optimizer in solvers]
#       3     if any(res.status == OptimizationResultStatus.SUCCESS for res in results):
#       4         with open(getPath("results"), 'a+') as file:
#       5             file.write("\n ------------------------------------- \n"+qp_name)
#
# ~/anaconda3/envs/Qiskit_Ocean/lib/python3.8/site-packages/qiskit/optimization/algorithms/minimum_eigen_optimizer.py in solve(self, problem)
#     184
#     185             # approximate ground state of operator using min eigen solver
# --> 186             eigen_result = self._min_eigen_solver.compute_minimum_eigenvalue(operator)
#     187
#     188             # analyze results
#
# ~/anaconda3/envs/Qiskit_Ocean/lib/python3.8/site-packages/dwave/plugins/qiskit/minimum_eigen_solvers/dwave_minimum_eigen_solver.py in compute_minimum_eigenvalue(self, operator, aux_operators)
#     183     ) -> MinimumEigensolverResult:
#     184         super().compute_minimum_eigenvalue(operator, aux_operators)
# --> 185         return self._run()
#     186
#     187     def _sample(self) -> dimod.SampleSet:
#
# ~/anaconda3/envs/Qiskit_Ocean/lib/python3.8/site-packages/dwave/plugins/qiskit/minimum_eigen_solvers/dwave_minimum_eigen_solver.py in _run(self)
#     217         """
#     218
# --> 219         sampleset = self._sample()
#     220
#     221         logger.debug('sampleset: %r', sampleset)
#
# ~/anaconda3/envs/Qiskit_Ocean/lib/python3.8/site-packages/dwave/plugins/qiskit/minimum_eigen_solvers/dwave_minimum_eigen_solver.py in _sample(self)
#     189         if 'num_reads' in self.sampler.parameters:
#     190             params['num_reads'] = self._num_reads
# --> 191         return self.sampler.sample(self.bqm, **params)
#     192
#     193     @staticmethod
#
# ~/anaconda3/envs/Qiskit_Ocean/lib/python3.8/site-packages/dwave/system/samplers/clique.py in sample(self, bqm, chain_strength, **kwargs)
#     199         # returns an empty embedding when the BQM is too large
#     200         if not embedding and bqm.num_variables:
# --> 201             raise ValueError("Cannot embed given BQM (size {}), sampler can "
#     202                              "only handle problems of size {}".format(
#     203                                 len(bqm.variables), self.largest_clique_size))
#
# ValueError: Cannot embed given BQM (size 129), sampler can only handle problems of size 120
