# %%
import os 
import shutil
import time

from random_lp.random_qp import RandomQP

DIR = 'TEST_DATA' + "/" + time.strftime("%d_%m_%Y")


def getPath(filename = "", directory = ""):
    return DIR + "/" + directory + "/" + filename
DIR
# Out:
# 'TEST_DATA/28_03_2021'

# %%
shutil.rmtree(DIR, ignore_errors=True)

# %%
os.makedirs(getPath(directory = "DENSE"))
os.makedirs(getPath(directory = "SPARSE"))

# %%
# we want up to 33 qubits since  ibmq_qasm_simulator has 32
max_qubits = 32

# %%
# create dense random binary quadratic programs
var = 3
while True:
    cstr = int(var / 2)
    qp_bin = RandomQP.create_random_binary_prog("test_dense_" + str(var), cstr, var)              
    qp_bin.write_to_lp_file(getPath(qp_bin.name, directory = "DENSE"))
    if qp_bin.complexity() > max_qubits :
        print(var)
        break
    var = var + 2
# Out:
# 15

# %%
# create sparse random binary quadratic programs
# 3 variables with 2 constraints each
var = 3
cstr = 2

multiple = 2
while True:
    qp_bin = RandomQP.create_random_binary_prog("test_sparse_" + str(multiple), cstr, var, multiple=multiple)            
    qp_bin.write_to_lp_file(getPath(qp_bin.name, directory = "SPARSE"))
    if qp_bin.complexity() > max_qubits :
        print(multiple)
        break
    multiple = multiple + 1
# Out:
# 6

# %%
qp_bin.qubo.to_docplex().prettyprint()
# Out:
# // This file has been generated by DOcplex
# // model name is: test_sparse_6
# // single vars section
# dvar bool x0_0;
# dvar bool x0_1;
# dvar bool x0_2;
# dvar bool x1_0;
# dvar bool x1_1;
# dvar bool x1_2;
# dvar bool x2_0;
# dvar bool x2_1;
# dvar bool x2_2;
# dvar bool x3_0;
# dvar bool x3_1;
# dvar bool x3_2;
# dvar bool x4_0;
# dvar bool x4_1;
# dvar bool x4_2;
# dvar bool x5_0;
# dvar bool x5_1;
# dvar bool x5_2;
# dvar bool A0_leb0@int_slack@0;
# dvar bool A0_leb0@int_slack@1;
# dvar bool A0_leb1@int_slack@0;
# dvar bool A0_leb1@int_slack@1;
# dvar bool A1_leb0@int_slack@0;
# dvar bool A1_leb0@int_slack@1;
# dvar bool A1_leb1@int_slack@0;
# dvar bool A1_leb1@int_slack@1;
# dvar bool A1_leb1@int_slack@2;
# dvar bool A2_leb1@int_slack@0;
# dvar bool A3_leb0@int_slack@0;
# dvar bool A3_leb0@int_slack@1;
# dvar bool A3_leb0@int_slack@2;
# dvar bool A3_leb1@int_slack@0;
# dvar bool A3_leb1@int_slack@1;
# dvar bool A4_leb0@int_slack@0;
# dvar bool A4_leb0@int_slack@1;
# dvar bool A4_leb1@int_slack@0;
# dvar bool A5_leb0@int_slack@0;
# dvar bool A5_leb1@int_slack@0;
# dvar bool A5_leb1@int_slack@1;
#
# minimize
#  - 87 x0_0 + 177 x0_1 + x0_2 - 529 x1_0 - 527 x1_1 + 527 x1_2 - 87 x2_0
#  + 89 x2_1 + 87 x2_2 + 88 x3_0 - 439 x3_1 + 177 x3_2 - 87 x4_0 - 89 x4_1
#  - 87 x4_2 - x5_0 - x5_1 + x5_2 - 88 A0_leb0@int_slack@0
#  - 176 A0_leb0@int_slack@1 - 88 A0_leb1@int_slack@0 - 88 A0_leb1@int_slack@1
#  - 176 A1_leb0@int_slack@0 - 352 A1_leb0@int_slack@1 - 352 A1_leb1@int_slack@0
#  - 704 A1_leb1@int_slack@1 - 704 A1_leb1@int_slack@2 - 264 A3_leb0@int_slack@0
#  - 528 A3_leb0@int_slack@1 - 264 A3_leb0@int_slack@2 - 176 A3_leb1@int_slack@0
#  - 352 A3_leb1@int_slack@1 + 88 A4_leb0@int_slack@0 + 88 A4_leb0@int_slack@1 [
#  44 x0_0^2 - 88 x0_0*x0_1 - 89 x0_0*x0_2 + 88 x0_0*A0_leb0@int_slack@0
#  + 176 x0_0*A0_leb0@int_slack@1 + 89 x0_1^2 + 2 x0_1*x0_2
#  - 88 x0_1*A0_leb0@int_slack@0 - 176 x0_1*A0_leb0@int_slack@1
#  - 88 x0_1*A0_leb1@int_slack@0 - 88 x0_1*A0_leb1@int_slack@1 + 88 x0_2^2
#  - 88 x0_2*A0_leb0@int_slack@0 - 176 x0_2*A0_leb0@int_slack@1
#  + 88 x0_2*A0_leb1@int_slack@0 + 88 x0_2*A0_leb1@int_slack@1 + 87 x1_0^2
#  + 175 x1_0*x1_1 - 176 x1_0*x1_2 + 88 x1_0*A1_leb0@int_slack@0
#  + 176 x1_0*A1_leb0@int_slack@1 + 88 x1_0*A1_leb1@int_slack@0
#  + 176 x1_0*A1_leb1@int_slack@1 + 176 x1_0*A1_leb1@int_slack@2 + 89 x1_1^2
#  - 177 x1_1*x1_2 + 88 x1_1*A1_leb0@int_slack@0 + 176 x1_1*A1_leb0@int_slack@1
#  + 88 x1_1*A1_leb1@int_slack@0 + 176 x1_1*A1_leb1@int_slack@1
#  + 176 x1_1*A1_leb1@int_slack@2 + 87 x1_2^2 - 88 x1_2*A1_leb0@int_slack@0
#  - 176 x1_2*A1_leb0@int_slack@1 - 88 x1_2*A1_leb1@int_slack@0
#  - 176 x1_2*A1_leb1@int_slack@1 - 176 x1_2*A1_leb1@int_slack@2 + 87 x2_0^2
#  - 175 x2_0*x2_1 - 87 x2_0*x2_2 - 88 x2_0*A2_leb1@int_slack@0 + 88 x2_1^2
#  + 89 x2_1*x2_2 + 88 x2_1*A2_leb1@int_slack@0 + 43 x2_2^2 + 89 x3_0^2
#  - 88 x3_0*x3_2 - 88 x3_0*A3_leb0@int_slack@0 - 176 x3_0*A3_leb0@int_slack@1
#  - 88 x3_0*A3_leb0@int_slack@2 + 88 x3_0*A3_leb1@int_slack@0
#  + 176 x3_0*A3_leb1@int_slack@1 + 89 x3_1^2 - 87 x3_1*x3_2
#  + 88 x3_1*A3_leb0@int_slack@0 + 176 x3_1*A3_leb0@int_slack@1
#  + 88 x3_1*A3_leb0@int_slack@2 + 88 x3_1*A3_leb1@int_slack@0
#  + 176 x3_1*A3_leb1@int_slack@1 + 43 x3_2^2 - 88 x3_2*A3_leb1@int_slack@0
#  - 176 x3_2*A3_leb1@int_slack@1 + 43 x4_0^2 + 89 x4_0*x4_1 + 89 x4_0*x4_2
#  - 88 x4_0*A4_leb0@int_slack@0 - 88 x4_0*A4_leb0@int_slack@1 + 45 x4_1^2
#  + 87 x4_1*x4_2 - 88 x4_1*A4_leb0@int_slack@0 - 88 x4_1*A4_leb0@int_slack@1
#  + 88 x4_2^2 - 88 x4_2*A4_leb0@int_slack@0 - 88 x4_2*A4_leb0@int_slack@1
#  - 88 x4_2*A4_leb1@int_slack@0 + 45 x5_0^2 + 88 x5_0*x5_1 + 88 x5_0*x5_2
#  - 88 x5_0*A5_leb1@int_slack@0 - 176 x5_0*A5_leb1@int_slack@1 + 88 x5_1^2
#  + 89 x5_1*x5_2 - 88 x5_1*A5_leb0@int_slack@0 - 88 x5_1*A5_leb1@int_slack@0
#  - 176 x5_1*A5_leb1@int_slack@1 + 45 x5_2^2 - 88 x5_2*A5_leb1@int_slack@0
#  - 176 x5_2*A5_leb1@int_slack@1 + 44 A0_leb0@int_slack@0^2
#  + 176 A0_leb0@int_slack@0*A0_leb0@int_slack@1 + 176 A0_leb0@int_slack@1^2
#  + 44 A0_leb1@int_slack@0^2 + 88 A0_leb1@int_slack@0*A0_leb1@int_slack@1
#  + 44 A0_leb1@int_slack@1^2 + 44 A1_leb0@int_slack@0^2
#  + 176 A1_leb0@int_slack@0*A1_leb0@int_slack@1 + 176 A1_leb0@int_slack@1^2
#  + 44 A1_leb1@int_slack@0^2 + 176 A1_leb1@int_slack@0*A1_leb1@int_slack@1
#  + 176 A1_leb1@int_slack@0*A1_leb1@int_slack@2 + 176 A1_leb1@int_slack@1^2
#  + 352 A1_leb1@int_slack@1*A1_leb1@int_slack@2 + 176 A1_leb1@int_slack@2^2
#  + 44 A2_leb1@int_slack@0^2 + 44 A3_leb0@int_slack@0^2
#  + 176 A3_leb0@int_slack@0*A3_leb0@int_slack@1
#  + 88 A3_leb0@int_slack@0*A3_leb0@int_slack@2 + 176 A3_leb0@int_slack@1^2
#  + 176 A3_leb0@int_slack@1*A3_leb0@int_slack@2 + 44 A3_leb0@int_slack@2^2
#  + 44 A3_leb1@int_slack@0^2 + 176 A3_leb1@int_slack@0*A3_leb1@int_slack@1
#  + 176 A3_leb1@int_slack@1^2 + 44 A4_leb0@int_slack@0^2
#  + 88 A4_leb0@int_slack@0*A4_leb0@int_slack@1 + 44 A4_leb0@int_slack@1^2
#  + 44 A4_leb1@int_slack@0^2 + 44 A5_leb0@int_slack@0^2
#  + 44 A5_leb1@int_slack@0^2 + 176 A5_leb1@int_slack@0*A5_leb1@int_slack@1
#  + 176 A5_leb1@int_slack@1^2 ] + 1628;
#
# subject to {
#
# }
