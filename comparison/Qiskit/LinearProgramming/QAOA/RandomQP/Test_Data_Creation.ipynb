# %%
import os 
import shutil
import time

from random_lp.random_qp import RandomQP

DIR = 'TEST_DATA' + "/" + time.strftime("%d_%m_%Y")


def getPath(filename = "", directory = ""):
    return DIR + "/" + directory + "/" + filename
DIR
# Out:
# 'TEST_DATA/27_03_2021'

# %%
shutil.rmtree(DIR, ignore_errors=True)

# %%
os.makedirs(getPath(directory = "DENSE"))
os.makedirs(getPath(directory = "SPARSE"))

# %%
# we want up to 33 qubits since  ibmq_qasm_simulator has 32
max_qubits = 32

# %%
# create dense random binary quadratic programs
var = 3
while True:
    cstr = int(var / 2)
    qp_bin = RandomQP.create_random_binary_prog("test_" + str(var), cstr, var)              
    qp_bin.write_to_lp_file(getPath(qp_bin.name, directory = "DENSE"))
    if qp_bin.complexity() > max_qubits :
        print(var)
        break
    var = var + 2
# Out:
# 15

# %%
# create sparse random binary quadratic programs
# 3 variables with 2 constraints each
var = 3
cstr = 2

multiple = 2
while True:
    qp_bin = RandomQP.create_random_binary_prog("test_" + str(multiple), cstr, var, multiple=multiple)            
    qp_bin.write_to_lp_file(getPath(qp_bin.name, directory = "SPARSE"))
    if qp_bin.complexity() > max_qubits :
        print(multiple)
        break
    multiple = multiple + 2
# Out:
# 6

# %%
qp_bin.qubo.to_docplex().prettyprint()
# Out:
# // This file has been generated by DOcplex
# // model name is: test_6
# // single vars section
# dvar bool x0_0;
# dvar bool x0_1;
# dvar bool x0_2;
# dvar bool x1_0;
# dvar bool x1_1;
# dvar bool x1_2;
# dvar bool x2_0;
# dvar bool x2_1;
# dvar bool x2_2;
# dvar bool x3_0;
# dvar bool x3_1;
# dvar bool x3_2;
# dvar bool x4_0;
# dvar bool x4_1;
# dvar bool x4_2;
# dvar bool x5_0;
# dvar bool x5_1;
# dvar bool x5_2;
# dvar bool A0_leb0@int_slack@0;
# dvar bool A0_leb0@int_slack@1;
# dvar bool A0_leb1@int_slack@0;
# dvar bool A0_leb1@int_slack@1;
# dvar bool A1_leb0@int_slack@0;
# dvar bool A1_leb0@int_slack@1;
# dvar bool A1_leb1@int_slack@0;
# dvar bool A1_leb1@int_slack@1;
# dvar bool A2_leb0@int_slack@0;
# dvar bool A2_leb1@int_slack@0;
# dvar bool A2_leb1@int_slack@1;
# dvar bool A3_leb1@int_slack@0;
# dvar bool A3_leb1@int_slack@1;
# dvar bool A4_leb0@int_slack@0;
# dvar bool A4_leb0@int_slack@1;
# dvar bool A4_leb1@int_slack@0;
# dvar bool A4_leb1@int_slack@1;
# dvar bool A5_leb0@int_slack@0;
# dvar bool A5_leb1@int_slack@0;
#
# minimize
#  - 217 x0_1 - 216 x0_2 - 145 x1_0 - 217 x1_1 - 71 x1_2 - 71 x2_0 - 216 x2_2
#  + 71 x3_0 + x3_1 - 73 x3_2 - 143 x4_0 - 144 x4_1 + 144 x4_2 - 73 x5_0
#  - 144 x5_1 - x5_2 - 216 A0_leb0@int_slack@0 - 432 A0_leb0@int_slack@1
#  - 144 A1_leb0@int_slack@0 - 144 A1_leb0@int_slack@1 - 72 A1_leb1@int_slack@0
#  - 72 A1_leb1@int_slack@1 - 72 A2_leb0@int_slack@0 - 216 A2_leb1@int_slack@0
#  - 432 A2_leb1@int_slack@1 - 72 A3_leb1@int_slack@0 - 72 A3_leb1@int_slack@1
#  - 144 A4_leb0@int_slack@0 - 288 A4_leb0@int_slack@1 - 72 A5_leb0@int_slack@0
#  + 72 A5_leb1@int_slack@0 [ 37 x0_0^2 + 71 x0_0*x0_1 + 72 x0_0*x0_2
#  - 72 x0_0*A0_leb1@int_slack@0 - 144 x0_0*A0_leb1@int_slack@1 + 72 x0_1^2
#  + 144 x0_1*x0_2 + 72 x0_1*A0_leb0@int_slack@0 + 144 x0_1*A0_leb0@int_slack@1
#  - 72 x0_1*A0_leb1@int_slack@0 - 144 x0_1*A0_leb1@int_slack@1 + 72 x0_2^2
#  + 72 x0_2*A0_leb0@int_slack@0 + 144 x0_2*A0_leb0@int_slack@1
#  - 72 x0_2*A0_leb1@int_slack@0 - 144 x0_2*A0_leb1@int_slack@1 + 37 x1_0^2
#  + 72 x1_0*x1_1 + 72 x1_0*x1_2 + 72 x1_0*A1_leb0@int_slack@0
#  + 72 x1_0*A1_leb0@int_slack@1 + 72 x1_1^2 + 2 x1_1*x1_2
#  + 72 x1_1*A1_leb0@int_slack@0 + 72 x1_1*A1_leb0@int_slack@1
#  + 72 x1_1*A1_leb1@int_slack@0 + 72 x1_1*A1_leb1@int_slack@1 + 71 x1_2^2
#  + 72 x1_2*A1_leb0@int_slack@0 + 72 x1_2*A1_leb0@int_slack@1
#  - 72 x1_2*A1_leb1@int_slack@0 - 72 x1_2*A1_leb1@int_slack@1 + 36 x2_0^2
#  + x2_0*x2_1 + 72 x2_0*A2_leb0@int_slack@0 - x2_1^2 + x2_1*x2_2 + 37 x2_2^2
#  + 72 x2_2*A2_leb1@int_slack@0 + 144 x2_2*A2_leb1@int_slack@1 + 37 x3_0^2
#  - 2 x3_0*x3_1 - 73 x3_0*x3_2 - 72 x3_0*A3_leb1@int_slack@0
#  - 72 x3_0*A3_leb1@int_slack@1 + 35 x3_2^2 + 72 x3_2*A3_leb1@int_slack@0
#  + 72 x3_2*A3_leb1@int_slack@1 + 72 x4_0^2 + 142 x4_0*x4_1 - 144 x4_0*x4_2
#  + 72 x4_0*A4_leb0@int_slack@0 + 144 x4_0*A4_leb0@int_slack@1
#  - 72 x4_0*A4_leb1@int_slack@0 - 72 x4_0*A4_leb1@int_slack@1 + 71 x4_1^2
#  - 145 x4_1*x4_2 + 72 x4_1*A4_leb0@int_slack@0 + 144 x4_1*A4_leb0@int_slack@1
#  - 72 x4_1*A4_leb1@int_slack@0 - 72 x4_1*A4_leb1@int_slack@1 + 72 x4_2^2
#  - 72 x4_2*A4_leb0@int_slack@0 - 144 x4_2*A4_leb0@int_slack@1
#  + 72 x4_2*A4_leb1@int_slack@0 + 72 x4_2*A4_leb1@int_slack@1 + 37 x5_0^2
#  + 71 x5_0*x5_1 - 72 x5_0*A5_leb1@int_slack@0 + 71 x5_1^2 + x5_1*x5_2
#  + 72 x5_1*A5_leb0@int_slack@0 - 72 x5_1*A5_leb1@int_slack@0 - x5_2^2
#  + 36 A0_leb0@int_slack@0^2 + 144 A0_leb0@int_slack@0*A0_leb0@int_slack@1
#  + 144 A0_leb0@int_slack@1^2 + 36 A0_leb1@int_slack@0^2
#  + 144 A0_leb1@int_slack@0*A0_leb1@int_slack@1 + 144 A0_leb1@int_slack@1^2
#  + 36 A1_leb0@int_slack@0^2 + 72 A1_leb0@int_slack@0*A1_leb0@int_slack@1
#  + 36 A1_leb0@int_slack@1^2 + 36 A1_leb1@int_slack@0^2
#  + 72 A1_leb1@int_slack@0*A1_leb1@int_slack@1 + 36 A1_leb1@int_slack@1^2
#  + 36 A2_leb0@int_slack@0^2 + 36 A2_leb1@int_slack@0^2
#  + 144 A2_leb1@int_slack@0*A2_leb1@int_slack@1 + 144 A2_leb1@int_slack@1^2
#  + 36 A3_leb1@int_slack@0^2 + 72 A3_leb1@int_slack@0*A3_leb1@int_slack@1
#  + 36 A3_leb1@int_slack@1^2 + 36 A4_leb0@int_slack@0^2
#  + 144 A4_leb0@int_slack@0*A4_leb0@int_slack@1 + 144 A4_leb0@int_slack@1^2
#  + 36 A4_leb1@int_slack@0^2 + 72 A4_leb1@int_slack@0*A4_leb1@int_slack@1
#  + 36 A4_leb1@int_slack@1^2 + 36 A5_leb0@int_slack@0^2
#  + 36 A5_leb1@int_slack@0^2 ] + 1116;
#
# subject to {
#
# }
