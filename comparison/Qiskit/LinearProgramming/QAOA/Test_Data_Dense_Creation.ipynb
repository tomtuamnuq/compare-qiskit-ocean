# %%
import os 
import shutil
import time

from random_lp.lp_random_gen import RandomLP

DIR = 'TEST_DATA' + "/" + time.strftime("%d_%m_%Y")


def getPath(filename = "", directory = ""):
    return DIR + "/" + directory + "/" + filename

# %%
shutil.rmtree(DIR, ignore_errors=True)

# %%
os.makedirs(getPath(directory = "DENSE"))

# %%
# create dense random binary Linear Programs
# we want up to 33 qubits since  ibmq_qasm_simulator has 32
max_qubits = 32
var = 3
while True:
    cstr = int(var / 2)
    lp_bin = RandomLP.create_random_binary_prog("test_" + str(var), cstr, var)              
    lp_bin.write_to_lp_file(getPath(lp_bin.name, directory = "DENSE"))
    if lp_bin.complexity() > max_qubits :
        print(var)
        break
    var = var + 2
# Out:
# 13

# %%
lp_bin.qubo.to_docplex().prettyprint()
# Out:
# // This file has been generated by DOcplex
# // model name is: test_13
# // single vars section
# dvar bool x0_0;
# dvar bool x0_1;
# dvar bool x0_2;
# dvar bool x0_3;
# dvar bool x0_4;
# dvar bool x0_5;
# dvar bool x0_6;
# dvar bool x0_7;
# dvar bool x0_8;
# dvar bool x0_9;
# dvar bool x0_10;
# dvar bool x0_11;
# dvar bool x0_12;
# dvar bool A0_leb0@int_slack@0;
# dvar bool A0_leb0@int_slack@1;
# dvar bool A0_leb0@int_slack@2;
# dvar bool A0_leb0@int_slack@3;
# dvar bool A0_leb1@int_slack@0;
# dvar bool A0_leb1@int_slack@1;
# dvar bool A0_leb1@int_slack@2;
# dvar bool A0_leb1@int_slack@3;
# dvar bool A0_leb2@int_slack@0;
# dvar bool A0_leb2@int_slack@1;
# dvar bool A0_leb2@int_slack@2;
# dvar bool A0_leb2@int_slack@3;
# dvar bool A0_leb3@int_slack@0;
# dvar bool A0_leb3@int_slack@1;
# dvar bool A0_leb3@int_slack@2;
# dvar bool A0_leb3@int_slack@3;
# dvar bool A0_leb4@int_slack@0;
# dvar bool A0_leb4@int_slack@1;
# dvar bool A0_leb4@int_slack@2;
# dvar bool A0_leb4@int_slack@3;
# dvar bool A0_leb4@int_slack@4;
# dvar bool A0_leb5@int_slack@0;
# dvar bool A0_leb5@int_slack@1;
# dvar bool A0_leb5@int_slack@2;
# dvar bool A0_leb5@int_slack@3;
#
# minimize
#  - 1621 x0_0 + 1226 x0_1 + 397 x0_2 + 1618 x0_3 - 324 x0_4 - 865 x0_5
#  - 937 x0_6 + 610 x0_7 - 326 x0_8 - 358 x0_9 - 1081 x0_10 - 1727 x0_11
#  - 935 x0_12 - 108 A0_leb2@int_slack@0 - 216 A0_leb2@int_slack@1
#  - 432 A0_leb2@int_slack@2 - 648 A0_leb2@int_slack@3 + 108 A0_leb3@int_slack@0
#  + 216 A0_leb3@int_slack@1 + 432 A0_leb3@int_slack@2 + 756 A0_leb3@int_slack@3
#  - 360 A0_leb4@int_slack@0 - 720 A0_leb4@int_slack@1
#  - 1440 A0_leb4@int_slack@2 - 2880 A0_leb4@int_slack@3
#  - 1440 A0_leb4@int_slack@4 - 72 A0_leb5@int_slack@0 - 144 A0_leb5@int_slack@1
#  - 288 A0_leb5@int_slack@2 - 432 A0_leb5@int_slack@3 [ 558 x0_0^2
#  - 180 x0_0*x0_1 - 468 x0_0*x0_2 - 648 x0_0*x0_3 - 360 x0_0*x0_4
#  + 288 x0_0*x0_5 + 612 x0_0*x0_6 - 648 x0_0*x0_7 + 576 x0_0*x0_8
#  + 360 x0_0*x0_9 - 252 x0_0*x0_10 + 1080 x0_0*x0_11 + 396 x0_0*x0_12
#  + 108 x0_0*A0_leb1@int_slack@0 + 216 x0_0*A0_leb1@int_slack@1
#  + 432 x0_0*A0_leb1@int_slack@2 + 540 x0_0*A0_leb1@int_slack@3
#  + 72 x0_0*A0_leb2@int_slack@0 + 144 x0_0*A0_leb2@int_slack@1
#  + 288 x0_0*A0_leb2@int_slack@2 + 432 x0_0*A0_leb2@int_slack@3
#  - 108 x0_0*A0_leb3@int_slack@0 - 216 x0_0*A0_leb3@int_slack@1
#  - 432 x0_0*A0_leb3@int_slack@2 - 756 x0_0*A0_leb3@int_slack@3
#  + 108 x0_0*A0_leb4@int_slack@0 + 216 x0_0*A0_leb4@int_slack@1
#  + 432 x0_0*A0_leb4@int_slack@2 + 864 x0_0*A0_leb4@int_slack@3
#  + 432 x0_0*A0_leb4@int_slack@4 + 450 x0_1^2 + 72 x0_1*x0_2 + 720 x0_1*x0_3
#  - 756 x0_1*x0_4 - 288 x0_1*x0_5 + 180 x0_1*x0_6 - 72 x0_1*x0_7 + 72 x0_1*x0_8
#  - 180 x0_1*x0_9 - 792 x0_1*x0_10 - 468 x0_1*x0_11 + 324 x0_1*x0_12
#  + 108 x0_1*A0_leb0@int_slack@0 + 216 x0_1*A0_leb0@int_slack@1
#  + 432 x0_1*A0_leb0@int_slack@2 + 216 x0_1*A0_leb0@int_slack@3
#  + 36 x0_1*A0_leb1@int_slack@0 + 72 x0_1*A0_leb1@int_slack@1
#  + 144 x0_1*A0_leb1@int_slack@2 + 180 x0_1*A0_leb1@int_slack@3
#  - 36 x0_1*A0_leb2@int_slack@0 - 72 x0_1*A0_leb2@int_slack@1
#  - 144 x0_1*A0_leb2@int_slack@2 - 216 x0_1*A0_leb2@int_slack@3
#  - 36 x0_1*A0_leb3@int_slack@0 - 72 x0_1*A0_leb3@int_slack@1
#  - 144 x0_1*A0_leb3@int_slack@2 - 252 x0_1*A0_leb3@int_slack@3
#  - 108 x0_1*A0_leb4@int_slack@0 - 216 x0_1*A0_leb4@int_slack@1
#  - 432 x0_1*A0_leb4@int_slack@2 - 864 x0_1*A0_leb4@int_slack@3
#  - 432 x0_1*A0_leb4@int_slack@4 - 72 x0_1*A0_leb5@int_slack@0
#  - 144 x0_1*A0_leb5@int_slack@1 - 288 x0_1*A0_leb5@int_slack@2
#  - 432 x0_1*A0_leb5@int_slack@3 + 486 x0_2^2 + 216 x0_2*x0_3 - 108 x0_2*x0_4
#  - 576 x0_2*x0_5 - 360 x0_2*x0_6 + 324 x0_2*x0_7 - 252 x0_2*x0_8
#  - 72 x0_2*x0_9 + 468 x0_2*x0_10 - 468 x0_2*x0_11
#  + 72 x0_2*A0_leb0@int_slack@0 + 144 x0_2*A0_leb0@int_slack@1
#  + 288 x0_2*A0_leb0@int_slack@2 + 144 x0_2*A0_leb0@int_slack@3
#  - 108 x0_2*A0_leb1@int_slack@0 - 216 x0_2*A0_leb1@int_slack@1
#  - 432 x0_2*A0_leb1@int_slack@2 - 540 x0_2*A0_leb1@int_slack@3
#  + 36 x0_2*A0_leb2@int_slack@0 + 72 x0_2*A0_leb2@int_slack@1
#  + 144 x0_2*A0_leb2@int_slack@2 + 216 x0_2*A0_leb2@int_slack@3
#  - 72 x0_2*A0_leb4@int_slack@0 - 144 x0_2*A0_leb4@int_slack@1
#  - 288 x0_2*A0_leb4@int_slack@2 - 576 x0_2*A0_leb4@int_slack@3
#  - 288 x0_2*A0_leb4@int_slack@4 + 108 x0_2*A0_leb5@int_slack@0
#  + 216 x0_2*A0_leb5@int_slack@1 + 432 x0_2*A0_leb5@int_slack@2
#  + 648 x0_2*A0_leb5@int_slack@3 + 576 x0_3^2 - 144 x0_3*x0_4 - 468 x0_3*x0_5
#  - 432 x0_3*x0_6 + 216 x0_3*x0_7 - 180 x0_3*x0_8 - 288 x0_3*x0_9
#  - 324 x0_3*x0_10 - 1008 x0_3*x0_11 - 288 x0_3*x0_12
#  + 108 x0_3*A0_leb0@int_slack@0 + 216 x0_3*A0_leb0@int_slack@1
#  + 432 x0_3*A0_leb0@int_slack@2 + 216 x0_3*A0_leb0@int_slack@3
#  + 36 x0_3*A0_leb1@int_slack@0 + 72 x0_3*A0_leb1@int_slack@1
#  + 144 x0_3*A0_leb1@int_slack@2 + 180 x0_3*A0_leb1@int_slack@3
#  - 108 x0_3*A0_leb2@int_slack@0 - 216 x0_3*A0_leb2@int_slack@1
#  - 432 x0_3*A0_leb2@int_slack@2 - 648 x0_3*A0_leb2@int_slack@3
#  + 72 x0_3*A0_leb3@int_slack@0 + 144 x0_3*A0_leb3@int_slack@1
#  + 288 x0_3*A0_leb3@int_slack@2 + 504 x0_3*A0_leb3@int_slack@3
#  - 108 x0_3*A0_leb4@int_slack@0 - 216 x0_3*A0_leb4@int_slack@1
#  - 432 x0_3*A0_leb4@int_slack@2 - 864 x0_3*A0_leb4@int_slack@3
#  - 432 x0_3*A0_leb4@int_slack@4 + 558 x0_4^2 + 144 x0_4*x0_5 - 576 x0_4*x0_6
#  + 432 x0_4*x0_7 - 360 x0_4*x0_8 + 72 x0_4*x0_9 + 792 x0_4*x0_10
#  - 180 x0_4*x0_11 - 720 x0_4*x0_12 - 108 x0_4*A0_leb0@int_slack@0
#  - 216 x0_4*A0_leb0@int_slack@1 - 432 x0_4*A0_leb0@int_slack@2
#  - 216 x0_4*A0_leb0@int_slack@3 - 36 x0_4*A0_leb1@int_slack@0
#  - 72 x0_4*A0_leb1@int_slack@1 - 144 x0_4*A0_leb1@int_slack@2
#  - 180 x0_4*A0_leb1@int_slack@3 - 72 x0_4*A0_leb2@int_slack@0
#  - 144 x0_4*A0_leb2@int_slack@1 - 288 x0_4*A0_leb2@int_slack@2
#  - 432 x0_4*A0_leb2@int_slack@3 + 108 x0_4*A0_leb3@int_slack@0
#  + 216 x0_4*A0_leb3@int_slack@1 + 432 x0_4*A0_leb3@int_slack@2
#  + 756 x0_4*A0_leb3@int_slack@3 + 72 x0_4*A0_leb4@int_slack@0
#  + 144 x0_4*A0_leb4@int_slack@1 + 288 x0_4*A0_leb4@int_slack@2
#  + 576 x0_4*A0_leb4@int_slack@3 + 288 x0_4*A0_leb4@int_slack@4
#  + 72 x0_4*A0_leb5@int_slack@0 + 144 x0_4*A0_leb5@int_slack@1
#  + 288 x0_4*A0_leb5@int_slack@2 + 432 x0_4*A0_leb5@int_slack@3 + 378 x0_5^2
#  + 432 x0_5*x0_6 - 288 x0_5*x0_7 + 36 x0_5*x0_8 - 288 x0_5*x0_9
#  + 144 x0_5*x0_10 + 396 x0_5*x0_11 + 360 x0_5*x0_12
#  - 36 x0_5*A0_leb0@int_slack@0 - 72 x0_5*A0_leb0@int_slack@1
#  - 144 x0_5*A0_leb0@int_slack@2 - 72 x0_5*A0_leb0@int_slack@3
#  + 36 x0_5*A0_leb2@int_slack@0 + 72 x0_5*A0_leb2@int_slack@1
#  + 144 x0_5*A0_leb2@int_slack@2 + 216 x0_5*A0_leb2@int_slack@3
#  + 36 x0_5*A0_leb3@int_slack@0 + 72 x0_5*A0_leb3@int_slack@1
#  + 144 x0_5*A0_leb3@int_slack@2 + 252 x0_5*A0_leb3@int_slack@3
#  + 108 x0_5*A0_leb4@int_slack@0 + 216 x0_5*A0_leb4@int_slack@1
#  + 432 x0_5*A0_leb4@int_slack@2 + 864 x0_5*A0_leb4@int_slack@3
#  + 432 x0_5*A0_leb4@int_slack@4 - 108 x0_5*A0_leb5@int_slack@0
#  - 216 x0_5*A0_leb5@int_slack@1 - 432 x0_5*A0_leb5@int_slack@2
#  - 648 x0_5*A0_leb5@int_slack@3 + 432 x0_6^2 - 324 x0_6*x0_7 + 180 x0_6*x0_8
#  - 396 x0_6*x0_10 + 576 x0_6*x0_11 + 936 x0_6*x0_12
#  + 36 x0_6*A0_leb0@int_slack@0 + 72 x0_6*A0_leb0@int_slack@1
#  + 144 x0_6*A0_leb0@int_slack@2 + 72 x0_6*A0_leb0@int_slack@3
#  + 36 x0_6*A0_leb2@int_slack@0 + 72 x0_6*A0_leb2@int_slack@1
#  + 144 x0_6*A0_leb2@int_slack@2 + 216 x0_6*A0_leb2@int_slack@3
#  - 108 x0_6*A0_leb3@int_slack@0 - 216 x0_6*A0_leb3@int_slack@1
#  - 432 x0_6*A0_leb3@int_slack@2 - 756 x0_6*A0_leb3@int_slack@3
#  + 72 x0_6*A0_leb4@int_slack@0 + 144 x0_6*A0_leb4@int_slack@1
#  + 288 x0_6*A0_leb4@int_slack@2 + 576 x0_6*A0_leb4@int_slack@3
#  + 288 x0_6*A0_leb4@int_slack@4 - 108 x0_6*A0_leb5@int_slack@0
#  - 216 x0_6*A0_leb5@int_slack@1 - 432 x0_6*A0_leb5@int_slack@2
#  - 648 x0_6*A0_leb5@int_slack@3 + 378 x0_7^2 - 540 x0_7*x0_8 + 144 x0_7*x0_9
#  + 216 x0_7*x0_10 - 576 x0_7*x0_11 - 180 x0_7*x0_12
#  - 36 x0_7*A0_leb0@int_slack@0 - 72 x0_7*A0_leb0@int_slack@1
#  - 144 x0_7*A0_leb0@int_slack@2 - 72 x0_7*A0_leb0@int_slack@3
#  - 108 x0_7*A0_leb1@int_slack@0 - 216 x0_7*A0_leb1@int_slack@1
#  - 432 x0_7*A0_leb1@int_slack@2 - 540 x0_7*A0_leb1@int_slack@3
#  - 108 x0_7*A0_leb2@int_slack@0 - 216 x0_7*A0_leb2@int_slack@1
#  - 432 x0_7*A0_leb2@int_slack@2 - 648 x0_7*A0_leb2@int_slack@3
#  - 36 x0_7*A0_leb4@int_slack@0 - 72 x0_7*A0_leb4@int_slack@1
#  - 144 x0_7*A0_leb4@int_slack@2 - 288 x0_7*A0_leb4@int_slack@3
#  - 144 x0_7*A0_leb4@int_slack@4 + 36 x0_7*A0_leb5@int_slack@0
#  + 72 x0_7*A0_leb5@int_slack@1 + 144 x0_7*A0_leb5@int_slack@2
#  + 216 x0_7*A0_leb5@int_slack@3 + 252 x0_8^2 + 144 x0_8*x0_9 - 360 x0_8*x0_10
#  + 540 x0_8*x0_11 - 36 x0_8*x0_12 + 108 x0_8*A0_leb1@int_slack@0
#  + 216 x0_8*A0_leb1@int_slack@1 + 432 x0_8*A0_leb1@int_slack@2
#  + 540 x0_8*A0_leb1@int_slack@3 + 72 x0_8*A0_leb2@int_slack@0
#  + 144 x0_8*A0_leb2@int_slack@1 + 288 x0_8*A0_leb2@int_slack@2
#  + 432 x0_8*A0_leb2@int_slack@3 - 36 x0_8*A0_leb3@int_slack@0
#  - 72 x0_8*A0_leb3@int_slack@1 - 144 x0_8*A0_leb3@int_slack@2
#  - 252 x0_8*A0_leb3@int_slack@3 + 342 x0_9^2 - 252 x0_9*x0_10 + 432 x0_9*x0_11
#  - 216 x0_9*x0_12 - 72 x0_9*A0_leb0@int_slack@0 - 144 x0_9*A0_leb0@int_slack@1
#  - 288 x0_9*A0_leb0@int_slack@2 - 144 x0_9*A0_leb0@int_slack@3
#  + 36 x0_9*A0_leb1@int_slack@0 + 72 x0_9*A0_leb1@int_slack@1
#  + 144 x0_9*A0_leb1@int_slack@2 + 180 x0_9*A0_leb1@int_slack@3
#  - 36 x0_9*A0_leb2@int_slack@0 - 72 x0_9*A0_leb2@int_slack@1
#  - 144 x0_9*A0_leb2@int_slack@2 - 216 x0_9*A0_leb2@int_slack@3
#  - 108 x0_9*A0_leb3@int_slack@0 - 216 x0_9*A0_leb3@int_slack@1
#  - 432 x0_9*A0_leb3@int_slack@2 - 756 x0_9*A0_leb3@int_slack@3
#  + 72 x0_9*A0_leb5@int_slack@0 + 144 x0_9*A0_leb5@int_slack@1
#  + 288 x0_9*A0_leb5@int_slack@2 + 432 x0_9*A0_leb5@int_slack@3 + 666 x0_10^2
#  - 108 x0_10*x0_11 - 180 x0_10*x0_12 - 108 x0_10*A0_leb1@int_slack@0
#  - 216 x0_10*A0_leb1@int_slack@1 - 432 x0_10*A0_leb1@int_slack@2
#  - 540 x0_10*A0_leb1@int_slack@3 + 36 x0_10*A0_leb2@int_slack@0
#  + 72 x0_10*A0_leb2@int_slack@1 + 144 x0_10*A0_leb2@int_slack@2
#  + 216 x0_10*A0_leb2@int_slack@3 + 108 x0_10*A0_leb3@int_slack@0
#  + 216 x0_10*A0_leb3@int_slack@1 + 432 x0_10*A0_leb3@int_slack@2
#  + 756 x0_10*A0_leb3@int_slack@3 + 108 x0_10*A0_leb4@int_slack@0
#  + 216 x0_10*A0_leb4@int_slack@1 + 432 x0_10*A0_leb4@int_slack@2
#  + 864 x0_10*A0_leb4@int_slack@3 + 432 x0_10*A0_leb4@int_slack@4
#  + 108 x0_10*A0_leb5@int_slack@0 + 216 x0_10*A0_leb5@int_slack@1
#  + 432 x0_10*A0_leb5@int_slack@2 + 648 x0_10*A0_leb5@int_slack@3 + 630 x0_11^2
#  + 288 x0_11*x0_12 - 72 x0_11*A0_leb0@int_slack@0
#  - 144 x0_11*A0_leb0@int_slack@1 - 288 x0_11*A0_leb0@int_slack@2
#  - 144 x0_11*A0_leb0@int_slack@3 + 72 x0_11*A0_leb1@int_slack@0
#  + 144 x0_11*A0_leb1@int_slack@1 + 288 x0_11*A0_leb1@int_slack@2
#  + 360 x0_11*A0_leb1@int_slack@3 + 108 x0_11*A0_leb2@int_slack@0
#  + 216 x0_11*A0_leb2@int_slack@1 + 432 x0_11*A0_leb2@int_slack@2
#  + 648 x0_11*A0_leb2@int_slack@3 - 108 x0_11*A0_leb3@int_slack@0
#  - 216 x0_11*A0_leb3@int_slack@1 - 432 x0_11*A0_leb3@int_slack@2
#  - 756 x0_11*A0_leb3@int_slack@3 + 108 x0_11*A0_leb4@int_slack@0
#  + 216 x0_11*A0_leb4@int_slack@1 + 432 x0_11*A0_leb4@int_slack@2
#  + 864 x0_11*A0_leb4@int_slack@3 + 432 x0_11*A0_leb4@int_slack@4 + 648 x0_12^2
#  + 108 x0_12*A0_leb0@int_slack@0 + 216 x0_12*A0_leb0@int_slack@1
#  + 432 x0_12*A0_leb0@int_slack@2 + 216 x0_12*A0_leb0@int_slack@3
#  - 72 x0_12*A0_leb1@int_slack@0 - 144 x0_12*A0_leb1@int_slack@1
#  - 288 x0_12*A0_leb1@int_slack@2 - 360 x0_12*A0_leb1@int_slack@3
#  + 36 x0_12*A0_leb2@int_slack@0 + 72 x0_12*A0_leb2@int_slack@1
#  + 144 x0_12*A0_leb2@int_slack@2 + 216 x0_12*A0_leb2@int_slack@3
#  - 108 x0_12*A0_leb3@int_slack@0 - 216 x0_12*A0_leb3@int_slack@1
#  - 432 x0_12*A0_leb3@int_slack@2 - 756 x0_12*A0_leb3@int_slack@3
#  + 72 x0_12*A0_leb4@int_slack@0 + 144 x0_12*A0_leb4@int_slack@1
#  + 288 x0_12*A0_leb4@int_slack@2 + 576 x0_12*A0_leb4@int_slack@3
#  + 288 x0_12*A0_leb4@int_slack@4 - 108 x0_12*A0_leb5@int_slack@0
#  - 216 x0_12*A0_leb5@int_slack@1 - 432 x0_12*A0_leb5@int_slack@2
#  - 648 x0_12*A0_leb5@int_slack@3 + 18 A0_leb0@int_slack@0^2
#  + 72 A0_leb0@int_slack@0*A0_leb0@int_slack@1
#  + 144 A0_leb0@int_slack@0*A0_leb0@int_slack@2
#  + 72 A0_leb0@int_slack@0*A0_leb0@int_slack@3 + 72 A0_leb0@int_slack@1^2
#  + 288 A0_leb0@int_slack@1*A0_leb0@int_slack@2
#  + 144 A0_leb0@int_slack@1*A0_leb0@int_slack@3 + 288 A0_leb0@int_slack@2^2
#  + 288 A0_leb0@int_slack@2*A0_leb0@int_slack@3 + 72 A0_leb0@int_slack@3^2
#  + 18 A0_leb1@int_slack@0^2 + 72 A0_leb1@int_slack@0*A0_leb1@int_slack@1
#  + 144 A0_leb1@int_slack@0*A0_leb1@int_slack@2
#  + 180 A0_leb1@int_slack@0*A0_leb1@int_slack@3 + 72 A0_leb1@int_slack@1^2
#  + 288 A0_leb1@int_slack@1*A0_leb1@int_slack@2
#  + 360 A0_leb1@int_slack@1*A0_leb1@int_slack@3 + 288 A0_leb1@int_slack@2^2
#  + 720 A0_leb1@int_slack@2*A0_leb1@int_slack@3 + 450 A0_leb1@int_slack@3^2
#  + 18 A0_leb2@int_slack@0^2 + 72 A0_leb2@int_slack@0*A0_leb2@int_slack@1
#  + 144 A0_leb2@int_slack@0*A0_leb2@int_slack@2
#  + 216 A0_leb2@int_slack@0*A0_leb2@int_slack@3 + 72 A0_leb2@int_slack@1^2
#  + 288 A0_leb2@int_slack@1*A0_leb2@int_slack@2
#  + 432 A0_leb2@int_slack@1*A0_leb2@int_slack@3 + 288 A0_leb2@int_slack@2^2
#  + 864 A0_leb2@int_slack@2*A0_leb2@int_slack@3 + 648 A0_leb2@int_slack@3^2
#  + 18 A0_leb3@int_slack@0^2 + 72 A0_leb3@int_slack@0*A0_leb3@int_slack@1
#  + 144 A0_leb3@int_slack@0*A0_leb3@int_slack@2
#  + 252 A0_leb3@int_slack@0*A0_leb3@int_slack@3 + 72 A0_leb3@int_slack@1^2
#  + 288 A0_leb3@int_slack@1*A0_leb3@int_slack@2
#  + 504 A0_leb3@int_slack@1*A0_leb3@int_slack@3 + 288 A0_leb3@int_slack@2^2
#  + 1008 A0_leb3@int_slack@2*A0_leb3@int_slack@3 + 882 A0_leb3@int_slack@3^2
#  + 18 A0_leb4@int_slack@0^2 + 72 A0_leb4@int_slack@0*A0_leb4@int_slack@1
#  + 144 A0_leb4@int_slack@0*A0_leb4@int_slack@2
#  + 288 A0_leb4@int_slack@0*A0_leb4@int_slack@3
#  + 144 A0_leb4@int_slack@0*A0_leb4@int_slack@4 + 72 A0_leb4@int_slack@1^2
#  + 288 A0_leb4@int_slack@1*A0_leb4@int_slack@2
#  + 576 A0_leb4@int_slack@1*A0_leb4@int_slack@3
#  + 288 A0_leb4@int_slack@1*A0_leb4@int_slack@4 + 288 A0_leb4@int_slack@2^2
#  + 1152 A0_leb4@int_slack@2*A0_leb4@int_slack@3
#  + 576 A0_leb4@int_slack@2*A0_leb4@int_slack@4 + 1152 A0_leb4@int_slack@3^2
#  + 1152 A0_leb4@int_slack@3*A0_leb4@int_slack@4 + 288 A0_leb4@int_slack@4^2
#  + 18 A0_leb5@int_slack@0^2 + 72 A0_leb5@int_slack@0*A0_leb5@int_slack@1
#  + 144 A0_leb5@int_slack@0*A0_leb5@int_slack@2
#  + 216 A0_leb5@int_slack@0*A0_leb5@int_slack@3 + 72 A0_leb5@int_slack@1^2
#  + 288 A0_leb5@int_slack@1*A0_leb5@int_slack@2
#  + 432 A0_leb5@int_slack@1*A0_leb5@int_slack@3 + 288 A0_leb5@int_slack@2^2
#  + 864 A0_leb5@int_slack@2*A0_leb5@int_slack@3 + 648 A0_leb5@int_slack@3^2 ] +
#  2196;
#
# subject to {
#
# }
